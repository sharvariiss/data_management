# %% [markdown]
# FAIR Principles Analysis of a Sample Dataset
# This notebook is a step-by-step classroom demo for Day 1.
#
# It shows how to:
#
# inspect a dataset,
# review its metadata,
# evaluate it against the FAIR principles,
# identify weaknesses and practical issues,
# summarize how well the dataset supports:
# Findable
# Accessible
# Interoperable
# Reusable
# The goal is not to build a perfect formal evaluator.
# The goal is to help students understand FAIR in practice.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.4.1)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp311-cp311-win_amd64.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 8.9 MB/s eta 0:00:00
# Collecting numpy>=1.26.0
#   Downloading numpy-2.4.4-cp311-cp311-win_amd64.whl (12.6 MB)
#      ---------------------------------------- 12.6/12.6 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata
#   Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
#      -------------------------------------- 349.0/349.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.4.4 pandas-3.0.2 tzdata-2026.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\HP\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (2.4.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
data = [
    {"city": "Karlsruhe", "date": "2025-01-01", "pm25": 18.2, "pm10": 27.4, "unit": "ug/m3", "source": "sensor_A"},
    {"city": "Heidelberg", "date": "2025-01-01", "pm25": 15.7, "pm10": 24.1, "unit": "ug/m3", "source": "sensor_B"},
    {"city": "Mannheim", "date": "2025-01-01", "pm25": None, "pm10": 30.2, "unit": "ug/m3", "source": "sensor_C"},
    {"city": "Karlsruhe", "date": "2025-01-02", "pm25": 19.4, "pm10": 28.0, "unit": "ug/m3", "source": "sensor_A"},
    {"city": "Heidelberg", "date": "2025-01-02", "pm25": 16.1, "pm10": None, "unit": "ug/m3", "source": "sensor_B"},
    {"city": "Karlsruhe", "date": "2025-01-02", "pm25": 19.4, "pm10": 28.0, "unit": "ug/m3", "source": "sensor_A"},  # duplicate row
]

df = pd.DataFrame(data)
df
# Out:
#          city        date  pm25  pm10   unit    source
# 0   Karlsruhe  2025-01-01  18.2  27.4  ug/m3  sensor_A
# 1  Heidelberg  2025-01-01  15.7  24.1  ug/m3  sensor_B
# 2    Mannheim  2025-01-01   NaN  30.2  ug/m3  sensor_C
# 3   Karlsruhe  2025-01-02  19.4  28.0  ug/m3  sensor_A
# 4  Heidelberg  2025-01-02  16.1   NaN  ug/m3  sensor_B
# 5   Karlsruhe  2025-01-02  19.4  28.0  ug/m3  sensor_A
